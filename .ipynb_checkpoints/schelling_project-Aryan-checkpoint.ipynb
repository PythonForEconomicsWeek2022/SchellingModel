# %%
import matplotlib.pyplot as plt
import itertools
import random
import copy

# %% [markdown]
# #### A. Create a class called **Schelling**, with attributes width (how many houses there are on the horizontal axis), height (how many houses on the vertical axis), empty_ratio (number of empty locations), similarity_threshold (the percentage of neighbours that you want to have in your neighbourhood), n_iterations (how many iterations of the Schelling process we do), races (number of races). (Note: we will add other attributes along the way).

# %%
class Schelling:
    
    def __init__(self,width,height,empty_ratio,similarity_threshold,n_iterations,races):
        self.width = width
        self.height = height
        self.empty_ratio = empty_ratio
        self.similarity_threshold = similarity_threshold
        self.n_iterations = n_iterations
        self.races = races
        
    def populate(self):
        self.empty_houses = []
        self.agents = {}
        self.all_houses = list(itertools.product(list(range(0,self.width)),list(range(0,self.height))))
        random.shuffle(self.all_houses)
        self.n_empty = int(self.width*self.height*self.empty_ratio)
        self.empty_houses = self.all_houses[-self.n_empty:]
        self.remaining_houses = self.all_houses[:-self.n_empty]
            
        for i in self.remaining_houses:
            self.agents[i] = random.randint(1,self.races)
        
    def plot_city(self):
        colour = {1:'r',2:'b',3:'g'}
        counter = 1
        fig, ax = plt.subplots()
        for key,value in self.agents.items():
            ax.scatter(key[0]+0.5,key[1]+0.5, marker = 's',s=500,c=colour[value])
        plt.subplots_adjust(left=0, right=0.6, bottom=0.1,top=1)
        plt.grid()
        plt.xticks(list(range(self.width)))
        plt.yticks(list(range(self.height)))
        plt.show()
        
    def is_unsatisfied(self,agent):
        neighbours = []
        for x in [-1,0,1]:
            for y in [-1,0,1]:
                if agent[0]+x >= 0 and agent[0]+x < self.width and agent[1]+y >= 0 and agent[1]+y < self.height:
                    neighbour = ((agent[0]+x, agent[1]+y))
                    neighbours.append(neighbour)
        neighbours.remove(agent)
        race = self.agents[agent]
        similarity_counter = 0
        for n in neighbours:
            if  race == self.agents.get(n,0):
                similarity_counter += 1
        similarity_ratio = similarity_counter/ len(neighbours)
        if similarity_ratio < self.similarity_threshold:
            return True 
        else:
            return False  
    
    def update(self):
        for n in self.all_houses:
            if n in self.empty_houses:
                pass
            elif self.is_unsatisfied(n) == True:
                rand = random.randint(0,len(self.empty_houses)-1)
                new_location = self.empty_houses.pop(rand)
                self.empty_houses.append(n)
                race = self.agents.pop(n)
                self.remaining_houses.append(new_location)
                self.agents[new_location] = race   
                
    def similarity_index(self):
        similarity_per_agent = []
        for n in self.all_houses:
            if n in self.empty_houses:
                pass
            else :
                neighbours = []
                for x in [-1,0,1]:
                    for y in [-1,0,1]:
                        if n[0]+x >= 0 and n[0]+x < self.width and n[1]+y >= 0 and n[1]+y < self.height:
                            neighbour = ((n[0]+x, n[1]+y))
                            neighbours.append(neighbour)
                neighbours.remove(n)
                race = self.agents[n]
                similarity_counter = 0
                for k in neighbours:
                    if  race == self.agents.get(k,0):
                        similarity_counter += 1
                similarity_ratio = similarity_counter/ len(neighbours)
                similarity_per_agent.append(similarity_ratio)
        similarity_index = sum(similarity_per_agent)/len(self.remaining_houses)
        similarity_index = 1 - similarity_index
        return similarity_index
    
    def simulation(self,similarity_index_threshold):
        self.populate()
        index = self.similarity_index()
        while index < similarity_index_threshold :
            self.plot_city()
            self.update()
            index = self.similarity_index()
            if index >= similarity_index_threshold: 
                break

# %%
city = Schelling(10,10,0.2,0.3,100,3)
#city.populate()
#city.plot_city()
#city.similarity_index()
#city.is_unsatisfied((5,3))
city.simulation(0.7805)

# %% [markdown]
# #### G. Use this class to generate some experiments, by playing with the parameters (size of the city, similarity threshold, number of races, etc.)
#
# Make several experiments to analyse how the results change when we change one parameter at the time.

# %%
class Schelling_Advanced:
    
    def __init__(self,width,height,empty_ratio,similarity_threshold,n_iterations,races):
        self.width = width
        self.height = height
        self.empty_ratio = empty_ratio
        self.similarity_threshold = similarity_threshold
        self.n_iterations = n_iterations
        self.races = races
        
    def populate(self):
        self.empty_houses = []
        self.agents = {}
        self.all_houses = list(itertools.product(list(range(0,self.width)),list(range(0,self.height))))
        random.shuffle(self.all_houses)
        self.n_empty = int(self.width*self.height*self.empty_ratio)
        self.empty_houses = self.all_houses[-self.n_empty:]
        self.remaining_houses = self.all_houses[:-self.n_empty]
            
        for i in self.remaining_houses:
            self.agents[i] = random.randint(1,self.races)
        
    def plot_city(self):
        colour = {1:'#641E16',2:'#CD6155',3:'#27AE60',4:'#5DADE2',5:'#1B4F72'}
        counter = 1
        fig, ax = plt.subplots()
        for key,value in self.agents.items():
            ax.scatter(key[0]+0.5,key[1]+0.5, marker = 's',s=250,c=colour[value])
        plt.subplots_adjust(left=0, right=0.6, bottom=0.1,top=1)
        plt.grid()
        plt.xticks(list(range(self.width)))
        plt.yticks(list(range(self.height)))
        plt.show()
        
    def is_unsatisfied(self,agent):
        neighbours = []
        for x in [-1,0,1]:
            for y in [-1,0,1]:
                if agent[0]+x >= 0 and agent[0]+x < self.width and agent[1]+y >= 0 and agent[1]+y < self.height:
                    neighbour = ((agent[0]+x, agent[1]+y))
                    neighbours.append(neighbour)
        neighbours.remove(agent)
        race = self.agents[agent]
        race_counter = {}
        similarity_counter = 0
        for n in range(0,len(neighbours)):
            if neighbours[n] in self.remaining_houses:
                race_neighbour = (self.agents[neighbours[n]])
                if race == 1:
                    if race_neighbour == 1:
                        similarity_counter += 1
                    if race_neighbour == 2:
                        similarity_counter += 0.8
                    if race_neighbour == 3:
                        similarity_counter += 0.4
                    if race_neighbour == 4:
                        similarity_counter += -0.2
                    if race_neighbour == 5:
                        similarity_counter += -0.6
                if race == 2:
                    if race_neighbour == 1:
                        similarity_counter += 0.8
                    if race_neighbour == 2:
                        similarity_counter += 1
                    if race_neighbour == 3:
                        similarity_counter += 0.6
                    if race_neighbour == 4:
                        similarity_counter += 0.2
                    if race_neighbour == 5:
                        similarity_counter += -0.4 
                if race == 3:
                    if race_neighbour == 1:
                        similarity_counter += 0.2
                    if race_neighbour == 2:
                        similarity_counter += 0.4
                    if race_neighbour == 3:
                        similarity_counter += 1
                    if race_neighbour == 4:
                        similarity_counter += 0.4
                    if race_neighbour == 5:
                        similarity_counter += 0.2
                if race == 4:
                    if race_neighbour == 1:
                        similarity_counter += -0.4
                    if race_neighbour == 2:
                        similarity_counter += 0.2
                    if race_neighbour == 3:
                        similarity_counter += 0.6
                    if race_neighbour == 4:
                        similarity_counter += 1
                    if race_neighbour == 5:
                        similarity_counter += 0.8
                if race == 5:
                    if race_neighbour == 1:
                        similarity_counter += -0.6
                    if race_neighbour == 2:
                        similarity_counter += -0.2
                    if race_neighbour == 3:
                        similarity_counter += 0.4
                    if race_neighbour == 4:
                        similarity_counter += 0.8
                    if race_neighbour == 5:
                        similarity_counter += 1
                
        #for n in neighbours:
            #if  race == self.agents.get(n,0):
                #similarity_counter += 1
        similarity_ratio = similarity_counter/ len(neighbours)
        #return race_counter
        if similarity_ratio < self.similarity_threshold:
            return True 
        else:
            return False  
    
    def update(self):
        for k in self.all_houses:
            if k in self.empty_houses:
                pass
            if k in self.agents.keys():
                if self.is_unsatisfied(k) == True:
                    #rand = random.randint(0,len(self.empty_houses)-1)
                    #new_location = self.empty_houses.pop(rand)
                    #self.empty_houses.append(k)
                    #race = self.agents.pop(k)
                    #self.remaining_houses.append(new_location)
                    #self.agents[new_location] = race 
                    
                    rand = random.randint(0,len(self.empty_houses)-1)
                    new_location = self.empty_houses[rand]
                    self.empty_houses.remove(self.empty_houses[rand])
                    self.empty_houses.append(k)
                    self.remaining_houses.append(new_location)
                    self.remaining_houses.remove(k)
                    race = self.agents[k]
                    self.agents[new_location] = race  
                    del self.agents[k]
                
    def similarity_index(self):
        similarity_per_agent = []
        for n in self.all_houses:
            if n in self.empty_houses:
                pass
            else :
                neighbours = []
                for x in [-1,0,1]:
                    for y in [-1,0,1]:
                        if n[0]+x >= 0 and n[0]+x < self.width and n[1]+y >= 0 and n[1]+y < self.height:
                            neighbour = ((n[0]+x, n[1]+y))
                            neighbours.append(neighbour)
                neighbours.remove(n)
                race = self.agents[n]
                similarity_counter = 0
                for k in neighbours:
                    if  race == self.agents.get(k,0):
                        similarity_counter += 1
                similarity_ratio = similarity_counter/ len(neighbours)
                similarity_per_agent.append(similarity_ratio)
        similarity_index = sum(similarity_per_agent)/len(self.remaining_houses)
        similarity_index = 1 - similarity_index
        return similarity_index
    
    def simulation(self,similarity_index_threshold):
        self.populate()
        index = self.similarity_index()
        while index < similarity_index_threshold :
            self.plot_city()
            self.update()
            index = self.similarity_index()
            if index >= similarity_index_threshold: 
                break

# %%
city_2 = Schelling_Advanced(15,15,0.2,0.4,100,5)
#city_2.populate()
#city_2.plot_city()
#city_2.is_unsatisfied((5,3))
#city_2.similarity_index()
#city.is_unsatisfied((5,3))
city_2.simulation(0.90)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-3a4b6322247c> in <module>
#       5 #city_2.similarity_index()
#       6 #city.is_unsatisfied((5,3))
# ----> 7 city_2.simulation(0.90)
#
# <ipython-input-27-199a68c7a220> in simulation(self, similarity_index_threshold)
#     164         index = self.similarity_index()
#     165         while index < similarity_index_threshold :
# --> 166             self.plot_city()
#     167             self.update()
#     168             index = self.similarity_index()
#
# <ipython-input-27-199a68c7a220> in plot_city(self)
#      26         fig, ax = plt.subplots()
#      27         for key,value in self.agents.items():
# ---> 28             ax.scatter(key[0]+0.5,key[1]+0.5, marker = 's',s=250,c=colour[value])
#      29         plt.subplots_adjust(left=0, right=0.6, bottom=0.1,top=1)
#      30         plt.grid()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4526
#    4527         self.add_collection(collection)
# -> 4528         self.autoscale_view()
#    4529
#    4530         return collection
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2493         handle_single_axis(
#    2494             scalex, self._autoscaleXon, self._shared_x_axes, 'intervalx',
# -> 2495             'minposx', self.xaxis, self._xmargin, x_stickies, self.set_xbound)
#    2496         handle_single_axis(
#    2497             scaley, self._autoscaleYon, self._shared_y_axes, 'intervaly',
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in handle_single_axis(scale, autoscaleon, shared_axes, interval, minpos, axis, margin, stickies, set_bound)
#    2470             # with streamplot.
#    2471             do_lower_margin = not np.any(np.isclose(x0, stickies))
# -> 2472             do_upper_margin = not np.any(np.isclose(x1, stickies))
#    2473             x0, x1 = axis._scale.limit_range_for_scale(x0, x1, minpos)
#    2474             x0t, x1t = transform.transform([x0, x1])
#
# <__array_function__ internals> in isclose(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2258             return less_equal(abs(x-y), atol + rtol * abs(y))
#    2259
# -> 2260     x = asanyarray(a)
#    2261     y = asanyarray(b)
#    2262
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asanyarray(a, dtype, order)
#     136
#     137     """
# --> 138     return array(a, dtype, copy=False, order=order, subok=True)
#     139
#     140
#
# KeyboardInterrupt:
